# %% [markdown]
# # Тестирование качества ответов модели DeepSeek-R1-Distill-Qwen-7B

# %%
import pandas as pd

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.metrics import root_mean_squared_error, mean_absolute_error
from sklearn.metrics import cohen_kappa_score

# %%
df_test = pd.read_excel('DeepSeek_test.xlsx')

# %%
df_test['predict'] = -2
for i in range(2000):
    if ('positive' in df_test['sentiment'][i]) and ('negative' not in df_test['sentiment'][i]) and ('neutral' not in df_test['sentiment'][i]):
        df_test.loc[i, 'predict'] = 2
    if ('neutral' in df_test['sentiment'][i]) and ('negative' not in df_test['sentiment'][i]) and ('positive' not in df_test['sentiment'][i]):
        df_test.loc[i, 'predict'] = 1
    if ('negative' in df_test['sentiment'][i]) and ('neutral' not in df_test['sentiment'][i]) and ('positive' not in df_test['sentiment'][i]):
        df_test.loc[i, 'predict'] = 0

# %%
df_test
# Out:
#       i_comment                                      text_response       time  \
# 0          8000  Okay, so I need to figure out the sentiment of...  35.726094
# 1          8001  Okay, I need to determine the sentiment of the...  26.031150
# 2          8002  Okay, so I need to determine the sentiment of ...  26.204930
# 3          8003  Okay, so I need to figure out the sentiment of...  38.960386
# 4          8004  Okay, so I'm trying to figure out the sentimen...  35.791315
# ...         ...                                                ...        ...
# 1995       9995  Okay, so I need to figure out the sentiment of...  27.586114
# 1996       9996  Okay, I need to determine the sentiment of the...  21.487391
# 1997       9997  Okay, so I need to figure out the sentiment of...  39.239643
# 1998       9998  Okay, so I need to figure out the sentiment of...  25.948371
# 1999       9999  Okay, I need to determine the sentiment of the...  23.176792
#
#      sentiment  predict
# 0     negative        0
# 1     positive        2
# 2     negative        0
# 3     negative        0
# 4     positive        2
# ...        ...      ...
# 1995  negative        0
# 1996  negative        0
# 1997  negative        0
# 1998   neutral        1
# 1999  negative        0
#
# [2000 rows x 5 columns]

# %%
data = pd.read_excel('marked_data.xlsx')[8000:]
data = data.reset_index()

# %%
df_test['labels'] = data['labels'] + 1
df_test['text'] = data['text']

# %%
df_test
# Out:
#       i_comment                                      text_response       time  \
# 0          8000  Okay, so I need to figure out the sentiment of...  35.726094
# 1          8001  Okay, I need to determine the sentiment of the...  26.031150
# 2          8002  Okay, so I need to determine the sentiment of ...  26.204930
# 3          8003  Okay, so I need to figure out the sentiment of...  38.960386
# 4          8004  Okay, so I'm trying to figure out the sentimen...  35.791315
# ...         ...                                                ...        ...
# 1995       9995  Okay, so I need to figure out the sentiment of...  27.586114
# 1996       9996  Okay, I need to determine the sentiment of the...  21.487391
# 1997       9997  Okay, so I need to figure out the sentiment of...  39.239643
# 1998       9998  Okay, so I need to figure out the sentiment of...  25.948371
# 1999       9999  Okay, I need to determine the sentiment of the...  23.176792
#
#      sentiment  predict  labels  \
# 0     negative        0       0
# 1     positive        2       2
# 2     negative        0       0
# 3     negative        0       0
# 4     positive        2       2
# ...        ...      ...     ...
# 1995  negative        0       2
# 1996  negative        0       0
# 1997  negative        0       0
# 1998   neutral        1       0
# 1999  negative        0       0
#
#                                                    text
# 0                                           Они уху ели
# 1     ну на самом деле то что индия нам дружественны...
# 2     Выгода только государствам . Людей что те что ...
# 3     Рублёв - в Барселоне, Медведев - в Монако, но ...
# 4                   Занесут ему чемодан ..он успокоится
# ...                                                 ...
# 1995                   Не, ну это вообще пи.дец...!😡😤😡😤
# 1996  Чего он сказал-то? Как назвал , оскорбил? Ниче...
# 1997  Они все , включая и эту НаЕбулину , живут в Пу...
# 1998   ну так власятм спасибо скажите , это их рук дело
# 1999  12 лет обращаюсь во все инстанции по вопросу у...
#
# [2000 rows x 7 columns]

# %%
print('accuracy', accuracy_score(df_test['labels'], df_test['predict']))
print('macro_precision', precision_score(df_test['labels'], df_test['predict'], average='macro'))
print('macro_recall', recall_score(df_test['labels'], df_test['predict'], average='macro'))
print('macro_f1', f1_score(df_test['labels'], df_test['predict'], average='macro'))
# Out:
# accuracy 0.5765
# macro_precision 0.5442590319300141
# macro_recall 0.5629182735701267
# macro_f1 0.5470942833886937

# %%
print('precision by class', precision_score(df_test['labels'], df_test['predict'], average=None))
print('recall by class', recall_score(df_test['labels'], df_test['predict'], average=None))
print('f1 by class', f1_score(df_test['labels'], df_test['predict'], average=None))
# Out:
# precision by class [0.6869207  0.48347107 0.46238532]
# recall by class [0.6785351  0.37864078 0.63157895]
# f1 by class [0.68270215 0.4246824  0.53389831]

# %%
confusion_matrix(df_test['labels'], df_test['predict'], labels=[0,1,2])
# Out:
# array([[667, 176, 140],
#        [231, 234, 153],
#        [ 73,  74, 252]], dtype=int64)

# %%
cohen_kappa_score(df_test['labels'], df_test['predict'], labels=None, weights= 'quadratic', sample_weight=None)
# Out:
# 0.43907933516934816
